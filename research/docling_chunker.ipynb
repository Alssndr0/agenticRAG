# %%
from docling.chunking import HybridChunker
from docling.document_converter import DocumentConverter
from transformers import AutoTokenizer

# %%
converter = DocumentConverter()
result = converter.convert(
    "/Users/alessandro/Development/generalRAG/data/original/Fact-Sheets.pdf"
)

# %%
result.document.pictures

# %%
# Initialize chunker with tokenizer and max tokens
tokenizer = AutoTokenizer.from_pretrained("Alibaba-NLP/gte-Qwen2-7B-instruct")
chunker = HybridChunker(tokenizer=tokenizer, max_tokens=400, merge_peers=True)

# %%
document_chunks = list(chunker.chunk(dl_doc=result.document))

# %%
def extract_chunk_metadata(chunk):
    metadata = {}

    # Extract headings if available
    metadata["headings"] = getattr(chunk.meta, "headings", None)

    # Extract filename from origin
    try:
        filename = chunk.meta.origin.filename
        if isinstance(filename, str):
            metadata["filename"] = [filename]
        elif isinstance(filename, list) and all(isinstance(f, str) for f in filename):
            metadata["filename"] = filename
        else:
            raise TypeError("filename must be a string or list of strings")
    except (AttributeError, TypeError, KeyError):
        metadata["filename"] = None

    # Extract MIME type
    metadata["mimetype"] = getattr(chunk.meta.origin, "mimetype", None)

    # Extract page numbers from provenance
    page_numbers = []
    try:
        for item in chunk.meta.doc_items:
            for prov in item.prov:
                if hasattr(prov, "page_no"):
                    page_numbers.append(prov.page_no)
        metadata["pages"] = sorted(set(page_numbers)) if page_numbers else None
    except Exception:
        metadata["pages"] = None

    # Extract bounding boxes and char spans from provenance
    bboxes = []
    charspans = []
    try:
        for item in chunk.meta.doc_items:
            for prov in item.prov:
                bbox = getattr(prov, "bbox", None)
                charspan = getattr(prov, "charspan", None)
                if bbox:
                    bboxes.append(
                        {
                            "left": bbox.l,
                            "top": bbox.t,
                            "right": bbox.r,
                            "bottom": bbox.b,
                            "origin": bbox.coord_origin.name,
                        }
                    )
                if charspan:
                    charspans.append({"start": charspan[0], "end": charspan[1]})
        metadata["bounding_boxes"] = bboxes if bboxes else None
        metadata["charspans"] = charspans if charspans else None
    except Exception:
        metadata["bounding_boxes"] = None
        metadata["charspans"] = None

    return {"chunk": chunk.text, "metadata": metadata}

# %%
all_extracted = [extract_chunk_metadata(chunk) for chunk in document_chunks]

# %%
all_extracted
# Out:
# [{'chunk': 'ENGIE Brasil Energia is an investment platform in energy infrastructure, active in the areas of generation, commercialization, trading and transmission as well as natural gas transportation, through the intermediary of Transportadora Associada de Gás - TAG, jointly with other partners. As the largest 100% renewable energy generator in the Brazilian private sector, implements and operates projects from renewable sources such as hydroelectric, wind farms, photovoltaic and biomass plants together with small hydroelectric plants. The Company operates with transparency, financial discipline, respect for the environment, support for communities and focus on operational efficiency as drivers of long-term growth.\nThe market cap, as of December 31, 2024, was R$ 29.0 billion, and the own installed capacity totaled 9,556 MW , which comprises a generating complex of 115 plants , of which 11 are hydroelectric power plants and 104 fired from complementary sources: two biomass-fired plants, 75 wind power plants, two small hydroelectric plants and 25 solar plants. In the transmission segment, the Gralha Azul, Novo Estado and Gavião Real Transmission Systems are in full operation.',
#   'metadata': {'headings': ['Corporate Overview'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [1],
#    'bounding_boxes': [{'left': 29.04,
#      'top': 605.363,
#      'right': 245.384,
#      'bottom': 455.741,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 29.04,
#      'top': 446.463,
#      'right': 245.357,
#      'bottom': 351.551,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 714}, {'start': 0, 'end': 467}]}},
#  {'chunk': 'ENGIE Brasil Energia is controlled by French group ENGIE, a global leader in the independent production of energy with its activities in around 30 countries. ENGIE is a major operator in the electricity, natural gas and energy services businesses with a worldwide electric energy capacity of about 100 GW holding 68.7% of the Brazilian company through ENGIE Brasil Participações Ltda.\nBalanced portfolio of business in energy infrastructure\nNote: 1 The transfer of 40% stake of ENGIE Brasil Participações in Jirau HPP to the Company should be examined timely.\nOwn installed capacity of 9,556 MW (4,661 aMW), 2,710 Km of transmission lines under operation and a stake of 17.5% in TAG.',
#   'metadata': {'headings': ['Ownership Structure'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [1],
#    'bounding_boxes': [{'left': 30.624,
#      'top': 297.323,
#      'right': 251.65,
#      'bottom': 220.56100000000004,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 311.16,
#      'top': 637.998,
#      'right': 500.701,
#      'bottom': 614.966,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 289.7,
#      'top': 429.669,
#      'right': 507.059,
#      'bottom': 414.349,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 300.26,
#      'top': 396.452,
#      'right': 509.207,
#      'bottom': 366.78,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 384},
#     {'start': 0, 'end': 55},
#     {'start': 0, 'end': 118},
#     {'start': 0, 'end': 123}]}},
#  {'chunk': 'Net Operating Revenue (NOR), 4Q24 = 3,271. Net Operating Revenue (NOR), 4Q23 = 2,711. Net Operating Revenue (NOR), Chg. = 20.7%. Net Operating Revenue (NOR), 12M24 = 11,219. Net Operating Revenue (NOR), 12M23 = 10,748. Net Operating Revenue (NOR), Chg. = 4.4%. Results from Operations (EBIT), 4Q24 = 1,685. Results from Operations (EBIT), 4Q23 = 1,570. Results from Operations (EBIT), Chg. = 7.3%. Results from Operations (EBIT), 12M24 = 7,682. Results from Operations (EBIT), 12M23 = 6,360. Results from Operations (EBIT), Chg. = 20.8%. Adjusted Ebitda 1, 4Q24 = 1,934. Adjusted Ebitda 1, 4Q23 = 1,638. Adjusted Ebitda 1, Chg. = 18.1%. Adjusted Ebitda 1, 12M24 = 7,367. Adjusted Ebitda 1, 12M23 = 7,270. Adjusted Ebitda 1, Chg. = 1.3%. Non-recurrent effects adjusted Ebitda 2, 4Q24 =',
#   'metadata': {'headings': ['Energy Balance (% of total; in aMW) | as of December 31, 2024'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [2],
#    'bounding_boxes': [{'left': 15.78456974029541,
#      'top': 642.9412231445312,
#      'right': 370.7767333984375,
#      'bottom': 472.35357666015625,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 0}]}},
#  {'chunk': '1,766. Non-recurrent effects adjusted Ebitda 2, 4Q23 = 1,586. Non-recurrent effects adjusted Ebitda 2, Chg. = 11.3%. Non-recurrent effects adjusted Ebitda 2, 12M24 = 6,907. Non-recurrent effects adjusted Ebitda 2, 12M23 = 7,028. Non-recurrent effects adjusted Ebitda 2, Chg. = -1.7%. Adjusted Ebitda / NOR - (%) 1, 4Q24 = 59.1. Adjusted Ebitda / NOR - (%) 1, 4Q23 = 60.4. Adjusted Ebitda / NOR - (%) 1, Chg. = -1.3 p.p.. Adjusted Ebitda / NOR - (%) 1, 12M24 = 65.7. Adjusted Ebitda / NOR - (%) 1, 12M23 = 67.6. Adjusted Ebitda / NOR - (%) 1, Chg. = -1.9 p.p.. Adjusted Net Income, 4Q24 = 1,060. Adjusted Net Income, 4Q23 = 819. Adjusted Net Income, Chg. = 29.4%. Adjusted Net Income, 12M24 = 3,372. Adjusted Net Income, 12M23 = 3,421. Adjusted Net Income, Chg. = -1.4%. Adjusted Return on Equity (ROE)',
#   'metadata': {'headings': ['Energy Balance (% of total; in aMW) | as of December 31, 2024'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [2],
#    'bounding_boxes': [{'left': 15.78456974029541,
#      'top': 642.9412231445312,
#      'right': 370.7767333984375,
#      'bottom': 472.35357666015625,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 0}]}},
#  {'chunk': '3, 4Q24 = 27.4. Adjusted Return on Equity (ROE) 3, 4Q23 = 34.9. Adjusted Return on Equity (ROE) 3, Chg. = -7.5 p.p.. Adjusted Return on Equity (ROE) 3, 12M24 = 27.4. Adjusted Return on Equity (ROE) 3, 12M23 = 34.9. Adjusted Return on Equity (ROE) 3, Chg. = -7.5 p.p.. Adjusted Return on Invested Capital (ROIC) 4, 4Q24 = 17.1. Adjusted Return on Invested Capital (ROIC) 4, 4Q23 = 20.3. Adjusted Return on Invested Capital (ROIC) 4, Chg. = -3.2 p.p.. Adjusted Return on Invested Capital (ROIC) 4, 12M24 = 17.2. Adjusted Return on Invested Capital (ROIC) 4, 12M23 = 20.3. Adjusted Return on Invested Capital (ROIC) 4, Chg. = -3.1 p.p.. Gross Power Production (avg MW) 5, 4Q24 = 6,110. Gross Power Production (avg MW) 5, 4Q23 = 6,694. Gross Power Production (avg MW) 5, Chg. = -8.7%. Gross Power Production (avg MW) 5, 12M24 =',
#   'metadata': {'headings': ['Energy Balance (% of total; in aMW) | as of December 31, 2024'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [2],
#    'bounding_boxes': [{'left': 15.78456974029541,
#      'top': 642.9412231445312,
#      'right': 370.7767333984375,
#      'bottom': 472.35357666015625,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 0}]}},
#  {'chunk': '6,173. Gross Power Production (avg MW) 5, 12M23 = 4,984. Gross Power Production (avg MW) 5, Chg. = 23.9%. Energy Sold (avg MW) 6, 4Q24 = 4,332. Energy Sold (avg MW) 6, 4Q23 = 3,940. Energy Sold (avg MW) 6, Chg. = 9.9%. Energy Sold (avg MW) 6, 12M24 = 4,106. Energy Sold (avg MW) 6, 12M23 = 4,088. Energy Sold (avg MW) 6, Chg. = 0.4%. Average Net Sales Price (R$/MWh) 7, 4Q24 = 224.93. Average Net Sales Price (R$/MWh) 7, 4Q23 = 229.33. Average Net Sales Price (R$/MWh) 7, Chg. = -1.9%. Average Net Sales Price (R$/MWh) 7, 12M24 = 220.79. Average Net Sales Price (R$/MWh) 7, 12M23 = 226.42. Average Net Sales Price (R$/MWh) 7, Chg. = -2.5%. Number of Employees - Total, 4Q24 = 1,210. Number of Employees - Total, 4Q23 = 1,136. Number of Employees - Total,',
#   'metadata': {'headings': ['Energy Balance (% of total; in aMW) | as of December 31, 2024'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [2],
#    'bounding_boxes': [{'left': 15.78456974029541,
#      'top': 642.9412231445312,
#      'right': 370.7767333984375,
#      'bottom': 472.35357666015625,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 0}]}},
#  {'chunk': 'Chg. = 6.5%. Number of Employees - Total, 12M24 = 1,210. Number of Employees - Total, 12M23 = 1,136. Number of Employees - Total, Chg. = 6.5%',
#   'metadata': {'headings': ['Energy Balance (% of total; in aMW) | as of December 31, 2024'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [2],
#    'bounding_boxes': [{'left': 15.78456974029541,
#      'top': 642.9412231445312,
#      'right': 370.7767333984375,
#      'bottom': 472.35357666015625,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 0}]}},
#  {'chunk': "1 Adjusted Ebitda: net income + income tax and social contribution + financial result + depreciation and amortization + impairment + non-recurrent.\n2 Adjusted EBITDA, net of IFRS effects from the transmission segment and quota plants.\n3 ROE: adjusted net income of the past 4 quarters / shareholders' equity.\n4 ROIC: effective rate x adjusted EBIT / invested capital (invested capital: debt - cash and cash equivalents - deposits earmarked for debt servicing + SE).\n5 Total gross electricity output from the plants operated by ENGIE Brasil Energia.\n6\nDisregarding sales for quotas regime (Jaguara and Miranda HPPs).\n7 Net of taxes and trading operations.",
#   'metadata': {'headings': ['Notes:'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [2],
#    'bounding_boxes': [{'left': 33.768,
#      'top': 462.266,
#      'right': 353.96,
#      'bottom': 457.417,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 33.768,
#      'top': 456.266,
#      'right': 231.342,
#      'bottom': 451.417,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 33.768,
#      'top': 450.266,
#      'right': 193.097,
#      'bottom': 445.417,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 33.768,
#      'top': 444.266,
#      'right': 374.234,
#      'bottom': 439.417,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 33.768,
#      'top': 438.266,
#      'right': 211.195,
#      'bottom': 433.417,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 33.768,
#      'top': 432.266,
#      'right': 35.636,
#      'bottom': 429.258,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 37.008,
#      'top': 431.929,
#      'right': 185.081,
#      'bottom': 427.417,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 33.768,
#      'top': 426.266,
#      'right': 115.692,
#      'bottom': 421.417,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 147},
#     {'start': 0, 'end': 86},
#     {'start': 0, 'end': 73},
#     {'start': 0, 'end': 156},
#     {'start': 0, 'end': 82},
#     {'start': 0, 'end': 1},
#     {'start': 0, 'end': 64},
#     {'start': 0, 'end': 38}]}},
#  {'chunk': '· By-law minimum payout: 30% of distributable net income.\n· Management commitment: minimum payout of 55% of distributable net income.\n· At least 2 dividends per year.',
#   'metadata': {'headings': ['Dividend Policy'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [2],
#    'bounding_boxes': [{'left': 30.84,
#      'top': 234.37300000000005,
#      'right': 260.899,
#      'bottom': 226.731,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 30.84,
#      'top': 221.413,
#      'right': 343.699,
#      'bottom': 213.77099999999996,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 30.84,
#      'top': 208.45299999999997,
#      'right': 154.189,
#      'bottom': 200.81100000000004,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 57},
#     {'start': 0, 'end': 75},
#     {'start': 0, 'end': 32}]}},
#  {'chunk': '1 Payout equivalent to 100% of the distributable adjusted net income (ex-hydrological risk negotiation).\n2 For the purposes of comparability between fiscal years, an adjustment in dividend per share was made in the light of the share bonus approved on December 07, 2018.\n3 Considers the annual adjusted net income.\n4 Based on volume-weighted closing price of ON shares in the period.\n5 Payout equivalent to 55% of the distributable net income (excluding gains on partial disposal of investments in TAG).\nISEB3\nICO2B3\nNet debt 1 (R$ million)\nNet debt/ LTM Adjusted Ebitda 2 (x)\n1 Debt net of hedge operations.\n2 Adjusted Ebitda in the past 12 months.',
#   'metadata': {'headings': ['Notes:'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [2],
#    'bounding_boxes': [{'left': 282.0,
#      'top': 157.889,
#      'right': 360.435,
#      'bottom': 141.36900000000003,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 282.0,
#      'top': 138.80899999999997,
#      'right': 366.545,
#      'bottom': 110.28899999999999,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 282.0,
#      'top': 107.84900000000005,
#      'right': 362.847,
#      'bottom': 97.33299999999997,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 282.0,
#      'top': 94.89300000000003,
#      'right': 364.396,
#      'bottom': 84.37300000000005,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 282.0,
#      'top': 82.89300000000003,
#      'right': 364.009,
#      'bottom': 60.37300000000005,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 33.666666666666664,
#      'top': 45.33333333333337,
#      'right': 87.66666666666667,
#      'bottom': 28.0,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 123.0,
#      'top': 46.66666666666663,
#      'right': 195.0,
#      'bottom': 28.66666666666663,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 276.41,
#      'top': 346.266,
#      'right': 323.938,
#      'bottom': 341.409,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 276.72,
#      'top': 335.179,
#      'right': 353.653,
#      'bottom': 330.659,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 262.9,
#      'top': 309.666,
#      'right': 331.63,
#      'bottom': 304.809,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 262.9,
#      'top': 303.666,
#      'right': 351.774,
#      'bottom': 298.809,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 104},
#     {'start': 0, 'end': 165},
#     {'start': 0, 'end': 43},
#     {'start': 0, 'end': 68},
#     {'start': 0, 'end': 119},
#     {'start': 0, 'end': 5},
#     {'start': 0, 'end': 6},
#     {'start': 0, 'end': 23},
#     {'start': 0, 'end': 35},
#     {'start': 0, 'end': 31},
#     {'start': 0, 'end': 40}]}},
#  {'chunk': 'Investors Relations Rua Paschoal Apóstolo Pítsica, 5064 Zip Code 88025-255 Florianópolis - SC Phone: +55 (48) 3221-7904 www.engie.com.br/investidores / ri.BREnergia@engie.com',
#   'metadata': {'headings': ['Adjusted Ebitda (R$ million)'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [2],
#    'bounding_boxes': [{'left': 400.61,
#      'top': 69.024,
#      'right': 508.39,
#      'bottom': 27.642000000000053,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 174}]}},
#  {'chunk': '4Q24 and 2024',
#   'metadata': {'headings': ['ENGIE Brasil Energia'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [3],
#    'bounding_boxes': [{'left': 27.408,
#      'top': 687.962,
#      'right': 195.334,
#      'bottom': 666.436,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 13}]}},
#  {'chunk': 'Purpose: act to accelerate the transition towards a carbon neutral society through reduced energy consumption and more environmentally sustainable solutions .',
#   'metadata': {'headings': ['ESG Highlights'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [3],
#    'bounding_boxes': [{'left': 31.104,
#      'top': 600.962,
#      'right': 351.412,
#      'bottom': 582.09,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 158}]}},
#  {'chunk': "· Reach water consumption related to the energy produced ratio of 0.1 m³/kWh (0.275m 3 /kWh in 2023).\nWater\n· Increase the participation of women in the Group's Management (HL 15+) of at least 40% (31.2% in 2023).\nGender equity\nGreenhouse gas emissions\n· Reduce to at least 43 MtCO e 2 the total emissions of greenhouse gases from the Group's electricity generation (51.8 MtCO 2 e in 2023).\nSupply Chain\n· Achievement of 100% of the responsible purchasing index (excluding energy purchases), which involve socio-environmental assessments and inclusive purchases; and achievement of 100%, by 2030, of the 250 preferred suppliers certified by Science Based Targets commitments (54% / 24% in 2023).\nRenewable energy\n· Increase the share of renewable sources in the mix of energy production capacity worldwide to 58% (41% in 2023. ENGIE Brasil Energia, 100% in 2023).",
#   'metadata': {'headings': ['Goals for 2030 - ENGIE Group'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [3],
#    'bounding_boxes': [{'left': 94.896,
#      'top': 537.732,
#      'right': 334.261,
#      'bottom': 514.417,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 83.832,
#      'top': 487.553,
#      'right': 105.452,
#      'bottom': 480.342,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 192.38,
#      'top': 486.852,
#      'right': 354.044,
#      'bottom': 453.86,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 137.59,
#      'top': 453.553,
#      'right': 164.259,
#      'bottom': 446.342,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 137.59,
#      'top': 453.553,
#      'right': 164.259,
#      'bottom': 446.342,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 157.56,
#      'top': 389.783,
#      'right': 208.686,
#      'bottom': 372.972,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 224.21,
#      'top': 440.452,
#      'right': 353.692,
#      'bottom': 384.186,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 137.59,
#      'top': 314.013,
#      'right': 185.34,
#      'bottom': 306.802,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 196.37,
#      'top': 362.652,
#      'right': 360.284,
#      'bottom': 264.86,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 83.832,
#      'top': 272.443,
#      'right': 123.67,
#      'bottom': 265.23199999999997,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 83.832,
#      'top': 272.443,
#      'right': 123.67,
#      'bottom': 265.23199999999997,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 66.984,
#      'top': 248.65200000000004,
#      'right': 239.916,
#      'bottom': 204.83000000000004,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 101},
#     {'start': 0, 'end': 5},
#     {'start': 0, 'end': 105},
#     {'start': 0, 'end': 6},
#     {'start': 7, 'end': 13},
#     {'start': 0, 'end': 24},
#     {'start': 0, 'end': 137},
#     {'start': 0, 'end': 12},
#     {'start': 0, 'end': 291},
#     {'start': 0, 'end': 9},
#     {'start': 10, 'end': 16},
#     {'start': 0, 'end': 150}]}},
#  {'chunk': '· Reduce emissions intensity (Scopes 1, 2 and 3) by 30% by 2025, and 56% by 2030 (0.034tco2/MWh in 2021);\n• Expansion of renewable energy capacity by 3.8 GW by 2030;\n· Engage 100% of major Scope 3 offending suppliers to set science-based targets by 2030;\n• Have 100% of assets covered by climate adaptation plans by 2030.\nNon-financial goals with a focus on:',
#   'metadata': {'headings': ['Goals for 2030 - ENGIE Brasil Energia Climate Journey'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [3],
#    'bounding_boxes': [{'left': 38.28,
#      'top': 153.77199999999993,
#      'right': 345.798,
#      'bottom': 131.58000000000004,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 38.28,
#      'top': 129.17200000000003,
#      'right': 289.494,
#      'bottom': 117.00900000000001,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 38.28,
#      'top': 115.37199999999996,
#      'right': 338.993,
#      'bottom': 93.18399999999997,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 38.28,
#      'top': 90.77599999999995,
#      'right': 314.312,
#      'bottom': 78.61300000000006,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 28.872,
#      'top': 382.483,
#      'right': 77.301,
#      'bottom': 356.072,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 105},
#     {'start': 0, 'end': 59},
#     {'start': 0, 'end': 88},
#     {'start': 0, 'end': 66},
#     {'start': 0, 'end': 36}]}},
#  {'chunk': 'Contribute to a better quality of life for people, through solutions that reduce the carbon footprints of cities, local authorities and companies.',
#   'metadata': {'headings': ['SOCIAL'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [4],
#    'bounding_boxes': [{'left': 43.944,
#      'top': 659.252,
#      'right': 270.411,
#      'bottom': 629.58,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 146}]}},
#  {'chunk': '· 3 main focuses of action\n· Access to culture and sport\n· Protection of children and youth\n· Income generation and social inclusion\n· Structuring Projects:\n· Women of Our Neighborhood\n· Partners for Wellbeing\n· Education Public Notice\n· 8 Culture and Sustainability Centers (2 under construction)\n· + R$ 315 million invested since 2008',
#   'metadata': {'headings': ['Social Responsibility:'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [4],
#    'bounding_boxes': [{'left': 43.944,
#      'top': 611.542,
#      'right': 154.551,
#      'bottom': 603.47,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 79.968,
#      'top': 600.742,
#      'right': 201.96,
#      'bottom': 592.67,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 79.968,
#      'top': 589.942,
#      'right': 219.906,
#      'bottom': 581.87,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 79.968,
#      'top': 579.142,
#      'right': 248.643,
#      'bottom': 571.07,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 43.944,
#      'top': 568.342,
#      'right': 138.639,
#      'bottom': 560.27,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 79.968,
#      'top': 557.542,
#      'right': 205.452,
#      'bottom': 549.47,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 79.968,
#      'top': 546.742,
#      'right': 177.03,
#      'bottom': 538.67,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 79.968,
#      'top': 535.942,
#      'right': 182.781,
#      'bottom': 527.87,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 43.944,
#      'top': 525.159,
#      'right': 233.776,
#      'bottom': 506.25,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 43.944,
#      'top': 503.522,
#      'right': 198.39,
#      'bottom': 495.45,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 26},
#     {'start': 0, 'end': 29},
#     {'start': 0, 'end': 34},
#     {'start': 0, 'end': 40},
#     {'start': 0, 'end': 23},
#     {'start': 0, 'end': 27},
#     {'start': 0, 'end': 24},
#     {'start': 0, 'end': 25},
#     {'start': 0, 'end': 61},
#     {'start': 0, 'end': 38}]}},
#  {'chunk': '· Diversity, equity and inclusion programs\n· 93% of the employees recommend ENGIE as a great place to work\nSocial action in\n+200 municipalities',
#   'metadata': {'headings': ['Employees:'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [4],
#    'bounding_boxes': [{'left': 43.944,
#      'top': 475.922,
#      'right': 210.738,
#      'bottom': 467.85,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 43.944,
#      'top': 465.122,
#      'right': 266.452,
#      'bottom': 446.25,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 51.24,
#      'top': 410.232,
#      'right': 111.72,
#      'bottom': 402.16,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 51.24,
#      'top': 398.475,
#      'right': 170.653,
#      'bottom': 386.851,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 42},
#     {'start': 0, 'end': 63},
#     {'start': 0, 'end': 16},
#     {'start': 0, 'end': 19}]}},
#  {'chunk': 'people impacted\nRegular\nstakeholder consultation and\nengagement process\nAttention to the Mental Health of employees',
#   'metadata': {'headings': ['+ 3.5 million'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [4],
#    'bounding_boxes': [{'left': 183.98,
#      'top': 394.442,
#      'right': 250.202,
#      'bottom': 386.37,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 67.632,
#      'top': 364.152,
#      'right': 101.778,
#      'bottom': 356.08,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 101.62,
#      'top': 367.035,
#      'right': 245.383,
#      'bottom': 355.411,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 113.26,
#      'top': 352.392,
#      'right': 197.32,
#      'bottom': 344.32,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 54.192,
#      'top': 327.055,
#      'right': 259.411,
#      'bottom': 315.431,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 15},
#     {'start': 0, 'end': 7},
#     {'start': 0, 'end': 28},
#     {'start': 0, 'end': 18},
#     {'start': 0, 'end': 43}]}},
#  {'chunk': 'Reconciling a positive impact on the planet and people with the performance of companies.',
#   'metadata': {'headings': ['GOVERNANCE'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [4],
#    'bounding_boxes': [{'left': 286.94,
#      'top': 658.612,
#      'right': 477.335,
#      'bottom': 639.74,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 89}]}},
#  {'chunk': "· Member, for 19 years, of the B3 Corporate Sustainability Index (ISE)\n· Member of B3's Carbon Efficient Index (ICO2) Portfolio for the fourth time\n· Sustainability Committee, reporting to the Board of Directors\n· Sustainability Panels in 9 Brazilian regions\n· Member of the Business Pact for Integrity and Against Corruption, an initiative of the Ethos Institute\n· Audit Committee, formed 100% by independent members\n· Board of Directors with 44% of independent members\n· Independent Committee for Transactions with Related Parties\n· Governance, Risks and Controls Management",
#   'metadata': {'headings': ['Governance'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [4],
#    'bounding_boxes': [{'left': 286.94,
#      'top': 617.852,
#      'right': 466.262,
#      'bottom': 598.976,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 286.94,
#      'top': 596.232,
#      'right': 515.996,
#      'bottom': 577.36,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 286.94,
#      'top': 574.632,
#      'right': 498.095,
#      'bottom': 555.76,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 286.94,
#      'top': 553.032,
#      'right': 463.778,
#      'bottom': 544.96,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 286.94,
#      'top': 542.232,
#      'right': 512.279,
#      'bottom': 523.36,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 286.94,
#      'top': 520.632,
#      'right': 486.35,
#      'bottom': 501.76,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 286.94,
#      'top': 499.032,
#      'right': 508.265,
#      'bottom': 490.96,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 286.94,
#      'top': 488.232,
#      'right': 512.135,
#      'bottom': 469.36,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 286.94,
#      'top': 466.632,
#      'right': 479.168,
#      'bottom': 458.56,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 70},
#     {'start': 0, 'end': 76},
#     {'start': 0, 'end': 63},
#     {'start': 0, 'end': 46},
#     {'start': 0, 'end': 104},
#     {'start': 0, 'end': 53},
#     {'start': 0, 'end': 52},
#     {'start': 0, 'end': 61},
#     {'start': 0, 'end': 43}]}},
#  {'chunk': 'in the MSCI 2024 review cycle\nRecognized among the\nBest of ESG\n2024 ,\npromoted by\nExame/Ibmec\nMember of Dow Jones Sustainability Emerging Markets Index 2024 - between the 6 best performances in the sector.',
#   'metadata': {'headings': ["'AA' rating"],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [4],
#    'bounding_boxes': [{'left': 300.98,
#      'top': 389.812,
#      'right': 370.616,
#      'bottom': 370.94,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 400.39,
#      'top': 414.912,
#      'right': 492.874,
#      'bottom': 406.84,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 400.39,
#      'top': 403.155,
#      'right': 479.213,
#      'bottom': 391.531,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 400.39,
#      'top': 387.572,
#      'right': 431.699,
#      'bottom': 375.927,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 400.39,
#      'top': 372.892,
#      'right': 452.743,
#      'bottom': 364.82,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 400.39,
#      'top': 362.092,
#      'right': 455.503,
#      'bottom': 354.02,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 292.73,
#      'top': 340.293,
#      'right': 508.72,
#      'bottom': 315.083,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 292.73,
#      'top': 340.293,
#      'right': 508.72,
#      'bottom': 315.083,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 29},
#     {'start': 0, 'end': 20},
#     {'start': 0, 'end': 11},
#     {'start': 0, 'end': 6},
#     {'start': 0, 'end': 11},
#     {'start': 0, 'end': 11},
#     {'start': 0, 'end': 72},
#     {'start': 73, 'end': 111}]}},
#  {'chunk': 'Contribute to the environment by reducing energy consumption and offering more sustainable solutions.',
#   'metadata': {'headings': ['ENVIRONMENT'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [4],
#    'bounding_boxes': [{'left': 43.944,
#      'top': 263.13200000000006,
#      'right': 456.942,
#      'bottom': 255.05999999999995,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 101}]}},
#  {'chunk': "· + R$ 22 billion destined to the energy transition (assets rotation 2016-2023).\n· 100% renewable generation park.\n•\nChosen by the ENGIE Group as a vehicle to lead investments and strategies to promote Green Hydrogen in Brazil.\n· Energy Place Platform supports our customers' decarbonization journey.",
#   'metadata': {'headings': ['Decarbonization'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [4],
#    'bounding_boxes': [{'left': 44.112,
#      'top': 235.73199999999997,
#      'right': 355.023,
#      'bottom': 227.65999999999997,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 44.112,
#      'top': 224.93200000000002,
#      'right': 186.336,
#      'bottom': 216.86,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 44.112,
#      'top': 214.13200000000006,
#      'right': 47.262,
#      'bottom': 206.05999999999995,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 51.912,
#      'top': 214.13200000000006,
#      'right': 507.951,
#      'bottom': 206.05999999999995,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 44.112,
#      'top': 203.332,
#      'right': 339.867,
#      'bottom': 195.26,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 80},
#     {'start': 0, 'end': 33},
#     {'start': 0, 'end': 1},
#     {'start': 0, 'end': 110},
#     {'start': 0, 'end': 72}]}},
#  {'chunk': "· Signatory of the Global Compact (UN), Coalizão Brasil and of the Action Declaration on Climate Policy Engagement.\n· Climate Journey approved by the Board, includes goals and strategies for mitigation, adaptation and climate resilience, in line with the ENGIE Group's 2030 goals.\n· + 6 billion seedlings planted/donated.\n+2,500\nprotected springs\nScore 'A-' from 2024 CDP Climate\nConservation Units supported\nGenerating complex\n100% renewable\nInvestors Relations Rua Paschoal Apóstolo Pítsica, 5064 Zip Code 88025-255 Florianópolis - SC Phone: +55 (48) 3221-7904 www.engie.com.br/investidores / ri.BREnergia@engie.com",
#   'metadata': {'headings': ['Environment'],
#    'filename': ['Fact-Sheets.pdf'],
#    'mimetype': 'application/pdf',
#    'pages': [4],
#    'bounding_boxes': [{'left': 44.112,
#      'top': 175.702,
#      'right': 516.837,
#      'bottom': 167.63,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 44.112,
#      'top': 164.90200000000004,
#      'right': 483.174,
#      'bottom': 146.02999999999997,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 44.112,
#      'top': 143.30200000000002,
#      'right': 200.349,
#      'bottom': 135.23000000000002,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 52.176,
#      'top': 95.57100000000003,
#      'right': 92.209,
#      'bottom': 83.947,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 52.176,
#      'top': 80.928,
#      'right': 92.577,
#      'bottom': 62.05600000000004,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 116.26,
#      'top': 96.52800000000002,
#      'right': 180.685,
#      'bottom': 51.25199999999995,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 212.4,
#      'top': 80.928,
#      'right': 268.128,
#      'bottom': 51.25199999999995,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 285.89,
#      'top': 96.52800000000002,
#      'right': 368.915,
#      'bottom': 88.45600000000002,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 285.89,
#      'top': 84.77099999999996,
#      'right': 349.485,
#      'bottom': 57.547000000000025,
#      'origin': 'BOTTOMLEFT'},
#     {'left': 408.98,
#      'top': 74.06399999999996,
#      'right': 516.77,
#      'bottom': 32.678,
#      'origin': 'BOTTOMLEFT'}],
#    'charspans': [{'start': 0, 'end': 115},
#     {'start': 0, 'end': 164},
#     {'start': 0, 'end': 40},
#     {'start': 0, 'end': 6},
#     {'start': 0, 'end': 17},
#     {'start': 0, 'end': 32},
#     {'start': 0, 'end': 28},
#     {'start': 0, 'end': 18},
#     {'start': 0, 'end': 14},
#     {'start': 0, 'end': 174}]}}]
